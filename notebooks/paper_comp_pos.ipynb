# %%
# Example analysis for a batch of experiments
# We found the functionalities below is the most useful in practice
# It can automatically provides an overview of the trade-off for each design dimension
from IPython.core.display import display, HTML

display(HTML("<style>.container { width:95% !important; }</style>"))
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import copy
from scipy.stats import rankdata
from matplotlib.ticker import MaxNLocator

# %matplotlib inline
sns.set(style='ticks',context='poster')
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 500)
np.set_printoptions(precision=3, linewidth=200, suppress=True)


def list_exclude(a, b):
    return [item for item in a if item not in b]

def chunks(lst, n):
    """Yield successive n-sized chunks from lst."""
    for i in range(0, len(lst), n):
        yield lst[i:i + n]
        
column_exclude_options = ['format','name', 'task', 'trans', 'feature', 'label',
            'epoch', 'loss', 'loss_std', 
            'params', 'time_iter', 'time_iter_std', 'accuracy', 'accuracy_std', 
            'precision', 'precision_std', 'recall', 'recall_std', 'f1', 'f1_std', 'auc', 'auc_std']

def name_mapping(name):
    # you can add additional name mapping for your customize configurations
    mapping = {'act': 'Activation', 'bn':'Batch Normalization', 'drop':'Dropout', 'agg':'Aggregation',
                'l_mp':'MP layers', 'l_pre':'Pre-process layers', 'l_post': 'Post-process layers', 'stage': 'Layer connectivity',
                'lr': 'Learning rate', 'batch':'Batch size', 'optim': 'Optimizer', 'epoch': 'Training epochs', 
                'direct': 'Direction', 'head':'Multi-task heads', 'l_final':'Att final', 'l_type':'layer_type',
               'l_finalbn': 'Final BN', 'task': 'Task', 'subgraph':'subgraph', 'margin':'margin',
               'order':'order', 'norm':'norm'}
    if name in mapping:
        return mapping[name]
    else:
        return name

def get_acc(df_pivot, name, ax, plot_type='performance', has_y=True, rank_resolution=0.001, verbose=False):
    accs_np = df_pivot.fillna(df_pivot.min()).values.round(4)
    options = df_pivot.columns.values

    ranks_raw = {'Model ID':[], 'Accuracy':[], 'Acc. Ranking':[], name_mapping(name):[]}
    
    for i,row in enumerate(accs_np):
        # (1) rank is asceneding, so we neg the row
        rank_base = -row
        med = np.median(rank_base)
        for j in range(len(rank_base)):
            if abs(rank_base[j]-med) <= rank_resolution:
                rank_base[j] = med
        rank = rankdata(rank_base, method='min')
        for j in range(len(rank)):
            ranks_raw['Model ID'].append(i)
            ranks_raw['Accuracy'].append(accs_np[i,j])
            ranks_raw['Acc. Ranking'].append(rank[j])
            ranks_raw[name_mapping(name)].append(options[j])
    
    ranks_raw = pd.DataFrame(data=ranks_raw)     
    with sns.color_palette("muted"):
        if plot_type=='performance':
            splot = sns.violinplot(x=name_mapping(name), y="Accuracy",inner="box", data=ranks_raw, cut=0, ax=ax)
            ax.set_xlabel('',fontsize=48)
            if not has_y:
                ax.set_ylabel('',fontsize=48)
            else:
                ax.set_ylabel('AUC Dist.',fontsize=48)
        elif plot_type=='rank_bar':
            splot = sns.barplot(x=name_mapping(name), y="Acc. Ranking",data=ranks_raw, ax=ax)
            ax.set_ylim(bottom=1)
            ax.set_yticks([1,2])
            ax.set_xlabel('',fontsize=48)
            if not has_y:
                ax.set_ylabel('',fontsize=48)
            else:
                ax.set_ylabel('Rank Average',fontsize=48)
        elif plot_type=='rank_violin':
            sns.violinplot(x=name_mapping(name), y="Acc. Ranking",inner="box", data=ranks_raw, cut=0, ax=ax)
            ax.set_ylim(bottom=1)
            ax.yaxis.set_major_locator(MaxNLocator(integer=True))
            if not has_y:
                ax.set_ylabel('',fontsize=48)
            else:
                ax.set_ylabel('Rank Dist.',fontsize=48)
        ax.xaxis.label.set_size(48)
        ax.yaxis.label.set_size(48)
        for tick in ax.xaxis.get_major_ticks():
            tick.label.set_fontsize(40)
        for tick in ax.yaxis.get_major_ticks():
            tick.label.set_fontsize(40)

            
def plot_single(df, options_chunk, options, metric, rank_resolution):
    for names in options_chunk:
        col = 6
        row = 3
        f, axes = plt.subplots(nrows=row, ncols=col, figsize=(48, 14))
        for i,name in enumerate(names):
            name_others = copy.deepcopy(options)
            name_others.remove(name)
            df_pivot = pd.pivot_table(df, values=metric, index=name_others, columns=[name], aggfunc=np.mean)
            for j,plot_type in enumerate(['performance','rank_bar','rank_violin']):
                get_acc(df_pivot, name, axes[j, i], plot_type, has_y=True, rank_resolution=rank_resolution)
        plt.tight_layout()
        plt.subplots_adjust(wspace=0.5, hspace=0.2)
    #     f.savefig('figs/{}.png'.format(metric), dpi=150, bbox_inches='tight')
        plt.show()

def plot_analysis(fname, division='test', dataset=None, metric='accuracy', rank_resolution=0.001, f=None, filter_rm=None):
    #results_file_path = '../run/results/{}/agg/{}.csv'.format(fname, division)
    results_file_path = '../results_experiments/{}/agg/{}.csv'.format(fname, division)
    df = pd.read_csv(results_file_path)
    df = df.fillna(0)
    #df['epoch'] += 1
    df.replace('skipconcat','skipcat',inplace=True)
    df.replace('add','sum',inplace=True)

    
    if f is not None:
        for key, val in f.items():
            if type(val) == list:
                df = df[df[key].isin(val)]
            else:
                df = df[df[key]==val]
      
    if filter_rm is not None:
        for key, val in filter_rm.items():
            if type(val) == list:
                df = df[~df[key].isin(val)]
            else:
                df = df[df[key]!=val]


    # create and filter design dimensions
    options_raw = list_exclude(list(df.columns), column_exclude_options)
    options = []
    for name in options_raw:
        column_temp = copy.deepcopy(options_raw)
        column_temp.remove(name)
        df_pivot = pd.pivot_table(df, values=metric, index=column_temp, columns=[name], aggfunc=np.mean)
        if len(df_pivot.columns)!=1:
            options.append(name)
    options_chunk = list(chunks(options, 6))
    print(division, dataset, options_chunk)
    
    if dataset is None:
        for dataset in df['name'].unique():
            df_dataset = df[df['name']==dataset]
            print('Dataset: {}'.format(dataset))
            plot_single(df_dataset, options_chunk, options, metric, rank_resolution)
    elif dataset=='all':
        plot_single(df, options_chunk, options, metric, rank_resolution)
    else:
        df_dataset = df[df['name']==dataset]
        print('Dataset: {}'.format(dataset))
        plot_single(df_dataset, options_chunk, options, metric, rank_resolution)
# Out:
# /tmp/ipykernel_54132/721938903.py:4: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML
# <style>.container { width:95% !important; }</style>

# %%
layers = ['gin', 'gat', 'gcn']
layers_cuda = ['gin']
archs = ['cpu', 'cuda']
datasets = ['PROTEINS', 'ENZYMES', 'DD', 'NCI1', 'BZR_MD', 'COX2_MD']

datasets_cpu = ['BZR_MD','COX2_MD', 'ENZYMES']
datasets_cuda = ['PROTEINS', 'DD', 'NCI1']
res_our = []
for layer in layers:
    for dataset in datasets_cpu:
        df = pd.read_csv(f'../../DL-project_results/tu_base_grid_{layer}_pos_cpu/agg/val_best.csv')
        
        df = df[df['dataset'] == dataset]#.sort_values('accuracy', ascending=False)

        if len(df) == 0:
            continue
        dilated = df[df['type'] == 'dilapos_gnn'].sort_values('accuracy', ascending=False)

        res_our.append({'arch': 'our', 'dataset': dataset, 'layer': layer, 'accuracy': dilated['accuracy'].iloc[0], 'accuracy_std': dilated['accuracy_std'].iloc[0], 'pos': dilated['pos'].iloc[0]  })


for layer in layers_cuda:
    for dataset in datasets_cuda:
        df = pd.read_csv(f'../../DL-project_results/tu_base_grid_{layer}_pos_cuda/agg/val_best.csv')
        
        df = df[df['dataset'] == dataset]#.sort_values('accuracy', ascending=False)

        if len(df) == 0:
            continue
        dilated = df[df['type'] == 'dilapos_gnn'].sort_values('accuracy', ascending=False)
        res_our.append({'arch': 'our', 'dataset': dataset, 'layer': layer, 'accuracy': dilated['accuracy'].iloc[0], 'accuracy_std': dilated['accuracy_std'].iloc[0], 'pos': dilated['pos'].iloc[0] })


pd.DataFrame(res_our).sort_values('layer')#['arch', 'dataset', 'accuracy', 'accuracy_our']
# Out:
#    arch   dataset layer  accuracy  accuracy_std    pos
# 3   our    BZR_MD   gat    0.8194        0.0438  False
# 4   our   COX2_MD   gat    0.8567        0.0775  False
# 5   our   ENZYMES   gat    0.7467        0.0476   True
# 6   our    BZR_MD   gcn    0.8097        0.0488   True
# 7   our   COX2_MD   gcn    0.7967        0.0752   True
# 8   our   ENZYMES   gcn    0.6633        0.0476  False
# 0   our    BZR_MD   gin    0.8000        0.0573  False
# 1   our   COX2_MD   gin    0.8100        0.0789   True
# 2   our   ENZYMES   gin    0.7333        0.0401  False
# 9   our  PROTEINS   gin    0.8027        0.0352  False
# 10  our        DD   gin    0.8297        0.0457  False
# 11  our      NCI1   gin    0.8470        0.0211  False

# %%
layer = 'gin'
d =  pd.read_csv(f'../../DL-project_results/tu_base_grid_{layer}_cuda/agg/val_best.csv')
d[d['dataset'] == 'PROTEINS'].sort_values('accuracy', ascending=False).head(1)
# Out:
#         d         type   dataset          layer  edges   k1   k2   h  \
# 196  cuda  dilated_gnn  PROTEINS  ginconv_paper  False  3.0  1.0  64
#
#      batch_size    lr  batchnorm   act  dropout                        gpool  \
# 196          32  0.01       True  relu      0.0  concat_across_sum_of_layers
#
#           scheduler  step_size  step_gamma     epoch  ckpt_epoch  \
# 196  step_lr_epochs         50         0.5  val_best        56.4
#
#      ckpt_epoch_std    loss  loss_std   params  time_iter  time_iter_std  \
# 196         40.1577  0.6277    0.1513  30723.0     0.2892         0.0106
#
#      accuracy  accuracy_std  precision  precision_std  recall  recall_std  \
# 196    0.7973        0.0358     0.7892         0.0517  0.7123       0.088
#
#          f1  f1_std     auc  auc_std  layers_mp
# 196  0.7454   0.057  0.8139   0.0397        NaN

# %%
pd.read_csv(f'../../DL-project_results/tu_base_grid_{layer}_cuda/agg/test_best.csv')
# Out:
#         d          type   dataset          layer  edges   k1   k2   h  \
# 0    cuda   dilated_gnn        DD  ginconv_paper  False  1.0  1.0  32
# 1    cuda   dilated_gnn        DD  ginconv_paper  False  1.0  1.0  32
# 2    cuda   dilated_gnn        DD  ginconv_paper  False  1.0  1.0  32
# 3    cuda   dilated_gnn        DD  ginconv_paper  False  1.0  1.0  32
# 4    cuda   dilated_gnn        DD  ginconv_paper  False  1.0  1.0  64
# 5    cuda   dilated_gnn        DD  ginconv_paper  False  1.0  1.0  64
# 6    cuda   dilated_gnn        DD  ginconv_paper  False  1.0  1.0  64
# 7    cuda   dilated_gnn        DD  ginconv_paper  False  1.0  1.0  64
# 8    cuda   dilated_gnn        DD  ginconv_paper  False  1.0  2.0  32
# 9    cuda   dilated_gnn        DD  ginconv_paper  False  1.0  2.0  32
# 10   cuda   dilated_gnn        DD  ginconv_paper  False  1.0  2.0  32
# 11   cuda   dilated_gnn        DD  ginconv_paper  False  1.0  2.0  32
# 12   cuda   dilated_gnn        DD  ginconv_paper  False  1.0  2.0  64
# 13   cuda   dilated_gnn        DD  ginconv_paper  False  1.0  2.0  64
# 14   cuda   dilated_gnn        DD  ginconv_paper  False  1.0  2.0  64
# 15   cuda   dilated_gnn        DD  ginconv_paper  False  1.0  2.0  64
# 16   cuda   dilated_gnn        DD  ginconv_paper  False  1.0  3.0  32
# 17   cuda   dilated_gnn        DD  ginconv_paper  False  1.0  3.0  32
# 18   cuda   dilated_gnn        DD  ginconv_paper  False  1.0  3.0  32
# 19   cuda   dilated_gnn        DD  ginconv_paper  False  1.0  3.0  32
# 20   cuda   dilated_gnn        DD  ginconv_paper  False  1.0  3.0  64
# 21   cuda   dilated_gnn        DD  ginconv_paper  False  1.0  3.0  64
# 22   cuda   dilated_gnn        DD  ginconv_paper  False  1.0  3.0  64
# 23   cuda   dilated_gnn        DD  ginconv_paper  False  1.0  3.0  64
# 24   cuda   dilated_gnn        DD  ginconv_paper  False  2.0  1.0  32
# 25   cuda   dilated_gnn        DD  ginconv_paper  False  2.0  1.0  32
# 26   cuda   dilated_gnn        DD  ginconv_paper  False  2.0  1.0  32
# 27   cuda   dilated_gnn        DD  ginconv_paper  False  2.0  1.0  32
# 28   cuda   dilated_gnn        DD  ginconv_paper  False  2.0  1.0  64
# 29   cuda   dilated_gnn        DD  ginconv_paper  False  2.0  1.0  64
# 30   cuda   dilated_gnn        DD  ginconv_paper  False  2.0  1.0  64
# 31   cuda   dilated_gnn        DD  ginconv_paper  False  2.0  1.0  64
# 32   cuda   dilated_gnn        DD  ginconv_paper  False  2.0  2.0  32
# 33   cuda   dilated_gnn        DD  ginconv_paper  False  2.0  2.0  32
# 34   cuda   dilated_gnn        DD  ginconv_paper  False  2.0  2.0  32
# 35   cuda   dilated_gnn        DD  ginconv_paper  False  2.0  2.0  32
# 36   cuda   dilated_gnn        DD  ginconv_paper  False  2.0  2.0  64
# 37   cuda   dilated_gnn        DD  ginconv_paper  False  2.0  2.0  64
# 38   cuda   dilated_gnn        DD  ginconv_paper  False  2.0  2.0  64
# 39   cuda   dilated_gnn        DD  ginconv_paper  False  2.0  2.0  64
# 40   cuda   dilated_gnn        DD  ginconv_paper  False  2.0  3.0  32
# 41   cuda   dilated_gnn        DD  ginconv_paper  False  2.0  3.0  32
# 42   cuda   dilated_gnn        DD  ginconv_paper  False  2.0  3.0  32
# 43   cuda   dilated_gnn        DD  ginconv_paper  False  2.0  3.0  32
# 44   cuda   dilated_gnn        DD  ginconv_paper  False  2.0  3.0  64
# 45   cuda   dilated_gnn        DD  ginconv_paper  False  2.0  3.0  64
# 46   cuda   dilated_gnn        DD  ginconv_paper  False  2.0  3.0  64
# 47   cuda   dilated_gnn        DD  ginconv_paper  False  2.0  3.0  64
# 48   cuda   dilated_gnn        DD  ginconv_paper  False  3.0  1.0  32
# 49   cuda   dilated_gnn        DD  ginconv_paper  False  3.0  1.0  32
# 50   cuda   dilated_gnn        DD  ginconv_paper  False  3.0  1.0  32
# 51   cuda   dilated_gnn        DD  ginconv_paper  False  3.0  1.0  32
# 52   cuda   dilated_gnn        DD  ginconv_paper  False  3.0  1.0  64
# 53   cuda   dilated_gnn        DD  ginconv_paper  False  3.0  1.0  64
# 54   cuda   dilated_gnn        DD  ginconv_paper  False  3.0  1.0  64
# 55   cuda   dilated_gnn        DD  ginconv_paper  False  3.0  1.0  64
# 56   cuda   dilated_gnn        DD  ginconv_paper  False  3.0  2.0  32
# 57   cuda   dilated_gnn        DD  ginconv_paper  False  3.0  2.0  32
# 58   cuda   dilated_gnn        DD  ginconv_paper  False  3.0  2.0  32
# 59   cuda   dilated_gnn        DD  ginconv_paper  False  3.0  2.0  32
# 60   cuda   dilated_gnn        DD  ginconv_paper  False  3.0  2.0  64
# 61   cuda   dilated_gnn        DD  ginconv_paper  False  3.0  2.0  64
# 62   cuda   dilated_gnn        DD  ginconv_paper  False  3.0  2.0  64
# 63   cuda   dilated_gnn        DD  ginconv_paper  False  3.0  2.0  64
# 64   cuda   dilated_gnn        DD  ginconv_paper  False  3.0  3.0  32
# 65   cuda   dilated_gnn        DD  ginconv_paper  False  3.0  3.0  32
# 66   cuda   dilated_gnn        DD  ginconv_paper  False  3.0  3.0  32
# 67   cuda   dilated_gnn        DD  ginconv_paper  False  3.0  3.0  32
# 68   cuda   dilated_gnn        DD  ginconv_paper  False  3.0  3.0  64
# 69   cuda   dilated_gnn        DD  ginconv_paper  False  3.0  3.0  64
# 70   cuda   dilated_gnn        DD  ginconv_paper  False  3.0  3.0  64
# 71   cuda   dilated_gnn        DD  ginconv_paper  False  3.0  3.0  64
# 72   cuda   dilated_gnn      NCI1  ginconv_paper  False  1.0  1.0  32
# 73   cuda   dilated_gnn      NCI1  ginconv_paper  False  1.0  1.0  32
# 74   cuda   dilated_gnn      NCI1  ginconv_paper  False  1.0  1.0  32
# 75   cuda   dilated_gnn      NCI1  ginconv_paper  False  1.0  1.0  32
# 76   cuda   dilated_gnn      NCI1  ginconv_paper  False  1.0  1.0  64
# 77   cuda   dilated_gnn      NCI1  ginconv_paper  False  1.0  1.0  64
# 78   cuda   dilated_gnn      NCI1  ginconv_paper  False  1.0  1.0  64
# 79   cuda   dilated_gnn      NCI1  ginconv_paper  False  1.0  1.0  64
# 80   cuda   dilated_gnn      NCI1  ginconv_paper  False  1.0  2.0  32
# 81   cuda   dilated_gnn      NCI1  ginconv_paper  False  1.0  2.0  32
# 82   cuda   dilated_gnn      NCI1  ginconv_paper  False  1.0  2.0  32
# 83   cuda   dilated_gnn      NCI1  ginconv_paper  False  1.0  2.0  32
# 84   cuda   dilated_gnn      NCI1  ginconv_paper  False  1.0  2.0  64
# 85   cuda   dilated_gnn      NCI1  ginconv_paper  False  1.0  2.0  64
# 86   cuda   dilated_gnn      NCI1  ginconv_paper  False  1.0  2.0  64
# 87   cuda   dilated_gnn      NCI1  ginconv_paper  False  1.0  2.0  64
# 88   cuda   dilated_gnn      NCI1  ginconv_paper  False  1.0  3.0  32
# 89   cuda   dilated_gnn      NCI1  ginconv_paper  False  1.0  3.0  32
# 90   cuda   dilated_gnn      NCI1  ginconv_paper  False  1.0  3.0  32
# 91   cuda   dilated_gnn      NCI1  ginconv_paper  False  1.0  3.0  32
# 92   cuda   dilated_gnn      NCI1  ginconv_paper  False  1.0  3.0  64
# 93   cuda   dilated_gnn      NCI1  ginconv_paper  False  1.0  3.0  64
# 94   cuda   dilated_gnn      NCI1  ginconv_paper  False  1.0  3.0  64
# 95   cuda   dilated_gnn      NCI1  ginconv_paper  False  1.0  3.0  64
# 96   cuda   dilated_gnn      NCI1  ginconv_paper  False  2.0  1.0  32
# 97   cuda   dilated_gnn      NCI1  ginconv_paper  False  2.0  1.0  32
# 98   cuda   dilated_gnn      NCI1  ginconv_paper  False  2.0  1.0  32
# 99   cuda   dilated_gnn      NCI1  ginconv_paper  False  2.0  1.0  32
# 100  cuda   dilated_gnn      NCI1  ginconv_paper  False  2.0  1.0  64
# 101  cuda   dilated_gnn      NCI1  ginconv_paper  False  2.0  1.0  64
# 102  cuda   dilated_gnn      NCI1  ginconv_paper  False  2.0  1.0  64
# 103  cuda   dilated_gnn      NCI1  ginconv_paper  False  2.0  1.0  64
# 104  cuda   dilated_gnn      NCI1  ginconv_paper  False  2.0  2.0  32
# 105  cuda   dilated_gnn      NCI1  ginconv_paper  False  2.0  2.0  32
# 106  cuda   dilated_gnn      NCI1  ginconv_paper  False  2.0  2.0  32
# 107  cuda   dilated_gnn      NCI1  ginconv_paper  False  2.0  2.0  32
# 108  cuda   dilated_gnn      NCI1  ginconv_paper  False  2.0  2.0  64
# 109  cuda   dilated_gnn      NCI1  ginconv_paper  False  2.0  2.0  64
# 110  cuda   dilated_gnn      NCI1  ginconv_paper  False  2.0  2.0  64
# 111  cuda   dilated_gnn      NCI1  ginconv_paper  False  2.0  2.0  64
# 112  cuda   dilated_gnn      NCI1  ginconv_paper  False  2.0  3.0  32
# 113  cuda   dilated_gnn      NCI1  ginconv_paper  False  2.0  3.0  32
# 114  cuda   dilated_gnn      NCI1  ginconv_paper  False  2.0  3.0  32
# 115  cuda   dilated_gnn      NCI1  ginconv_paper  False  2.0  3.0  32
# 116  cuda   dilated_gnn      NCI1  ginconv_paper  False  2.0  3.0  64
# 117  cuda   dilated_gnn      NCI1  ginconv_paper  False  2.0  3.0  64
# 118  cuda   dilated_gnn      NCI1  ginconv_paper  False  2.0  3.0  64
# 119  cuda   dilated_gnn      NCI1  ginconv_paper  False  2.0  3.0  64
# 120  cuda   dilated_gnn      NCI1  ginconv_paper  False  3.0  1.0  32
# 121  cuda   dilated_gnn      NCI1  ginconv_paper  False  3.0  1.0  32
# 122  cuda   dilated_gnn      NCI1  ginconv_paper  False  3.0  1.0  32
# 123  cuda   dilated_gnn      NCI1  ginconv_paper  False  3.0  1.0  32
# 124  cuda   dilated_gnn      NCI1  ginconv_paper  False  3.0  1.0  64
# 125  cuda   dilated_gnn      NCI1  ginconv_paper  False  3.0  1.0  64
# 126  cuda   dilated_gnn      NCI1  ginconv_paper  False  3.0  1.0  64
# 127  cuda   dilated_gnn      NCI1  ginconv_paper  False  3.0  1.0  64
# 128  cuda   dilated_gnn      NCI1  ginconv_paper  False  3.0  2.0  32
# 129  cuda   dilated_gnn      NCI1  ginconv_paper  False  3.0  2.0  32
# 130  cuda   dilated_gnn      NCI1  ginconv_paper  False  3.0  2.0  32
# 131  cuda   dilated_gnn      NCI1  ginconv_paper  False  3.0  2.0  32
# 132  cuda   dilated_gnn      NCI1  ginconv_paper  False  3.0  2.0  64
# 133  cuda   dilated_gnn      NCI1  ginconv_paper  False  3.0  2.0  64
# 134  cuda   dilated_gnn      NCI1  ginconv_paper  False  3.0  2.0  64
# 135  cuda   dilated_gnn      NCI1  ginconv_paper  False  3.0  2.0  64
# 136  cuda   dilated_gnn      NCI1  ginconv_paper  False  3.0  3.0  32
# 137  cuda   dilated_gnn      NCI1  ginconv_paper  False  3.0  3.0  32
# 138  cuda   dilated_gnn      NCI1  ginconv_paper  False  3.0  3.0  32
# 139  cuda   dilated_gnn      NCI1  ginconv_paper  False  3.0  3.0  32
# 140  cuda   dilated_gnn      NCI1  ginconv_paper  False  3.0  3.0  64
# 141  cuda   dilated_gnn      NCI1  ginconv_paper  False  3.0  3.0  64
# 142  cuda   dilated_gnn      NCI1  ginconv_paper  False  3.0  3.0  64
# 143  cuda   dilated_gnn      NCI1  ginconv_paper  False  3.0  3.0  64
# 144  cuda   dilated_gnn  PROTEINS  ginconv_paper  False  1.0  1.0  32
# 145  cuda   dilated_gnn  PROTEINS  ginconv_paper  False  1.0  1.0  32
# 146  cuda   dilated_gnn  PROTEINS  ginconv_paper  False  1.0  1.0  32
# 147  cuda   dilated_gnn  PROTEINS  ginconv_paper  False  1.0  1.0  32
# 148  cuda   dilated_gnn  PROTEINS  ginconv_paper  False  1.0  1.0  64
# 149  cuda   dilated_gnn  PROTEINS  ginconv_paper  False  1.0  1.0  64
# 150  cuda   dilated_gnn  PROTEINS  ginconv_paper  False  1.0  1.0  64
# 151  cuda   dilated_gnn  PROTEINS  ginconv_paper  False  1.0  1.0  64
# 152  cuda   dilated_gnn  PROTEINS  ginconv_paper  False  1.0  2.0  32
# 153  cuda   dilated_gnn  PROTEINS  ginconv_paper  False  1.0  2.0  32
# 154  cuda   dilated_gnn  PROTEINS  ginconv_paper  False  1.0  2.0  32
# 155  cuda   dilated_gnn  PROTEINS  ginconv_paper  False  1.0  2.0  32
# 156  cuda   dilated_gnn  PROTEINS  ginconv_paper  False  1.0  2.0  64
# 157  cuda   dilated_gnn  PROTEINS  ginconv_paper  False  1.0  2.0  64
# 158  cuda   dilated_gnn  PROTEINS  ginconv_paper  False  1.0  2.0  64
# 159  cuda   dilated_gnn  PROTEINS  ginconv_paper  False  1.0  2.0  64
# 160  cuda   dilated_gnn  PROTEINS  ginconv_paper  False  1.0  3.0  32
# 161  cuda   dilated_gnn  PROTEINS  ginconv_paper  False  1.0  3.0  32
# 162  cuda   dilated_gnn  PROTEINS  ginconv_paper  False  1.0  3.0  32
# 163  cuda   dilated_gnn  PROTEINS  ginconv_paper  False  1.0  3.0  32
# 164  cuda   dilated_gnn  PROTEINS  ginconv_paper  False  1.0  3.0  64
# 165  cuda   dilated_gnn  PROTEINS  ginconv_paper  False  1.0  3.0  64
# 166  cuda   dilated_gnn  PROTEINS  ginconv_paper  False  1.0  3.0  64
# 167  cuda   dilated_gnn  PROTEINS  ginconv_paper  False  1.0  3.0  64
# 168  cuda   dilated_gnn  PROTEINS  ginconv_paper  False  2.0  1.0  32
# 169  cuda   dilated_gnn  PROTEINS  ginconv_paper  False  2.0  1.0  32
# 170  cuda   dilated_gnn  PROTEINS  ginconv_paper  False  2.0  1.0  32
# 171  cuda   dilated_gnn  PROTEINS  ginconv_paper  False  2.0  1.0  32
# 172  cuda   dilated_gnn  PROTEINS  ginconv_paper  False  2.0  1.0  64
# 173  cuda   dilated_gnn  PROTEINS  ginconv_paper  False  2.0  1.0  64
# 174  cuda   dilated_gnn  PROTEINS  ginconv_paper  False  2.0  1.0  64
# 175  cuda   dilated_gnn  PROTEINS  ginconv_paper  False  2.0  1.0  64
# 176  cuda   dilated_gnn  PROTEINS  ginconv_paper  False  2.0  2.0  32
# 177  cuda   dilated_gnn  PROTEINS  ginconv_paper  False  2.0  2.0  32
# 178  cuda   dilated_gnn  PROTEINS  ginconv_paper  False  2.0  2.0  32
# 179  cuda   dilated_gnn  PROTEINS  ginconv_paper  False  2.0  2.0  32
# 180  cuda   dilated_gnn  PROTEINS  ginconv_paper  False  2.0  2.0  64
# 181  cuda   dilated_gnn  PROTEINS  ginconv_paper  False  2.0  2.0  64
# 182  cuda   dilated_gnn  PROTEINS  ginconv_paper  False  2.0  2.0  64
# 183  cuda   dilated_gnn  PROTEINS  ginconv_paper  False  2.0  2.0  64
# 184  cuda   dilated_gnn  PROTEINS  ginconv_paper  False  2.0  3.0  32
# 185  cuda   dilated_gnn  PROTEINS  ginconv_paper  False  2.0  3.0  32
# 186  cuda   dilated_gnn  PROTEINS  ginconv_paper  False  2.0  3.0  32
# 187  cuda   dilated_gnn  PROTEINS  ginconv_paper  False  2.0  3.0  32
# 188  cuda   dilated_gnn  PROTEINS  ginconv_paper  False  2.0  3.0  64
# 189  cuda   dilated_gnn  PROTEINS  ginconv_paper  False  2.0  3.0  64
# 190  cuda   dilated_gnn  PROTEINS  ginconv_paper  False  2.0  3.0  64
# 191  cuda   dilated_gnn  PROTEINS  ginconv_paper  False  2.0  3.0  64
# 192  cuda   dilated_gnn  PROTEINS  ginconv_paper  False  3.0  1.0  32
# 193  cuda   dilated_gnn  PROTEINS  ginconv_paper  False  3.0  1.0  32
# 194  cuda   dilated_gnn  PROTEINS  ginconv_paper  False  3.0  1.0  32
# 195  cuda   dilated_gnn  PROTEINS  ginconv_paper  False  3.0  1.0  32
# 196  cuda   dilated_gnn  PROTEINS  ginconv_paper  False  3.0  1.0  64
# 197  cuda   dilated_gnn  PROTEINS  ginconv_paper  False  3.0  1.0  64
# 198  cuda   dilated_gnn  PROTEINS  ginconv_paper  False  3.0  1.0  64
# 199  cuda   dilated_gnn  PROTEINS  ginconv_paper  False  3.0  1.0  64
# 200  cuda   dilated_gnn  PROTEINS  ginconv_paper  False  3.0  2.0  32
# 201  cuda   dilated_gnn  PROTEINS  ginconv_paper  False  3.0  2.0  32
# 202  cuda   dilated_gnn  PROTEINS  ginconv_paper  False  3.0  2.0  32
# 203  cuda   dilated_gnn  PROTEINS  ginconv_paper  False  3.0  2.0  32
# 204  cuda   dilated_gnn  PROTEINS  ginconv_paper  False  3.0  2.0  64
# 205  cuda   dilated_gnn  PROTEINS  ginconv_paper  False  3.0  2.0  64
# 206  cuda   dilated_gnn  PROTEINS  ginconv_paper  False  3.0  2.0  64
# 207  cuda   dilated_gnn  PROTEINS  ginconv_paper  False  3.0  2.0  64
# 208  cuda   dilated_gnn  PROTEINS  ginconv_paper  False  3.0  3.0  32
# 209  cuda   dilated_gnn  PROTEINS  ginconv_paper  False  3.0  3.0  32
# 210  cuda   dilated_gnn  PROTEINS  ginconv_paper  False  3.0  3.0  32
# 211  cuda   dilated_gnn  PROTEINS  ginconv_paper  False  3.0  3.0  32
# 212  cuda   dilated_gnn  PROTEINS  ginconv_paper  False  3.0  3.0  64
# 213  cuda   dilated_gnn  PROTEINS  ginconv_paper  False  3.0  3.0  64
# 214  cuda   dilated_gnn  PROTEINS  ginconv_paper  False  3.0  3.0  64
# 215  cuda   dilated_gnn  PROTEINS  ginconv_paper  False  3.0  3.0  64
# 216  cuda  standard_gnn        DD  ginconv_paper    NaN  NaN  NaN  32
# 217  cuda  standard_gnn        DD  ginconv_paper    NaN  NaN  NaN  32
# 218  cuda  standard_gnn        DD  ginconv_paper    NaN  NaN  NaN  32
# 219  cuda  standard_gnn        DD  ginconv_paper    NaN  NaN  NaN  32
# 220  cuda  standard_gnn        DD  ginconv_paper    NaN  NaN  NaN  32
# 221  cuda  standard_gnn        DD  ginconv_paper    NaN  NaN  NaN  32
# 222  cuda  standard_gnn        DD  ginconv_paper    NaN  NaN  NaN  32
# 223  cuda  standard_gnn        DD  ginconv_paper    NaN  NaN  NaN  32
# 224  cuda  standard_gnn        DD  ginconv_paper    NaN  NaN  NaN  64
# 225  cuda  standard_gnn        DD  ginconv_paper    NaN  NaN  NaN  64
# 226  cuda  standard_gnn        DD  ginconv_paper    NaN  NaN  NaN  64
# 227  cuda  standard_gnn        DD  ginconv_paper    NaN  NaN  NaN  64
# 228  cuda  standard_gnn        DD  ginconv_paper    NaN  NaN  NaN  64
# 229  cuda  standard_gnn        DD  ginconv_paper    NaN  NaN  NaN  64
# 230  cuda  standard_gnn        DD  ginconv_paper    NaN  NaN  NaN  64
# 231  cuda  standard_gnn        DD  ginconv_paper    NaN  NaN  NaN  64
# 232  cuda  standard_gnn      NCI1  ginconv_paper    NaN  NaN  NaN  32
# 233  cuda  standard_gnn      NCI1  ginconv_paper    NaN  NaN  NaN  32
# 234  cuda  standard_gnn      NCI1  ginconv_paper    NaN  NaN  NaN  32
# 235  cuda  standard_gnn      NCI1  ginconv_paper    NaN  NaN  NaN  32
# 236  cuda  standard_gnn      NCI1  ginconv_paper    NaN  NaN  NaN  32
# 237  cuda  standard_gnn      NCI1  ginconv_paper    NaN  NaN  NaN  32
# 238  cuda  standard_gnn      NCI1  ginconv_paper    NaN  NaN  NaN  32
# 239  cuda  standard_gnn      NCI1  ginconv_paper    NaN  NaN  NaN  32
# 240  cuda  standard_gnn      NCI1  ginconv_paper    NaN  NaN  NaN  64
# 241  cuda  standard_gnn      NCI1  ginconv_paper    NaN  NaN  NaN  64
# 242  cuda  standard_gnn      NCI1  ginconv_paper    NaN  NaN  NaN  64
# 243  cuda  standard_gnn      NCI1  ginconv_paper    NaN  NaN  NaN  64
# 244  cuda  standard_gnn      NCI1  ginconv_paper    NaN  NaN  NaN  64
# 245  cuda  standard_gnn      NCI1  ginconv_paper    NaN  NaN  NaN  64
# 246  cuda  standard_gnn      NCI1  ginconv_paper    NaN  NaN  NaN  64
# 247  cuda  standard_gnn      NCI1  ginconv_paper    NaN  NaN  NaN  64
# 248  cuda  standard_gnn  PROTEINS  ginconv_paper    NaN  NaN  NaN  32
# 249  cuda  standard_gnn  PROTEINS  ginconv_paper    NaN  NaN  NaN  32
# 250  cuda  standard_gnn  PROTEINS  ginconv_paper    NaN  NaN  NaN  32
# 251  cuda  standard_gnn  PROTEINS  ginconv_paper    NaN  NaN  NaN  32
# 252  cuda  standard_gnn  PROTEINS  ginconv_paper    NaN  NaN  NaN  32
# 253  cuda  standard_gnn  PROTEINS  ginconv_paper    NaN  NaN  NaN  32
# 254  cuda  standard_gnn  PROTEINS  ginconv_paper    NaN  NaN  NaN  32
# 255  cuda  standard_gnn  PROTEINS  ginconv_paper    NaN  NaN  NaN  32
# 256  cuda  standard_gnn  PROTEINS  ginconv_paper    NaN  NaN  NaN  64
# 257  cuda  standard_gnn  PROTEINS  ginconv_paper    NaN  NaN  NaN  64
# 258  cuda  standard_gnn  PROTEINS  ginconv_paper    NaN  NaN  NaN  64
# 259  cuda  standard_gnn  PROTEINS  ginconv_paper    NaN  NaN  NaN  64
# 260  cuda  standard_gnn  PROTEINS  ginconv_paper    NaN  NaN  NaN  64
# 261  cuda  standard_gnn  PROTEINS  ginconv_paper    NaN  NaN  NaN  64
# 262  cuda  standard_gnn  PROTEINS  ginconv_paper    NaN  NaN  NaN  64
# 263  cuda  standard_gnn  PROTEINS  ginconv_paper    NaN  NaN  NaN  64
#
#      batch_size    lr  batchnorm   act  dropout                        gpool  \
# 0            32  0.01       True  relu      0.0  concat_across_sum_of_layers
# 1            32  0.01       True  relu      0.5  concat_across_sum_of_layers
# 2           128  0.01       True  relu      0.0  concat_across_sum_of_layers
# 3           128  0.01       True  relu      0.5  concat_across_sum_of_layers
# 4            32  0.01       True  relu      0.0  concat_across_sum_of_layers
# 5            32  0.01       True  relu      0.5  concat_across_sum_of_layers
# 6           128  0.01       True  relu      0.0  concat_across_sum_of_layers
# 7           128  0.01       True  relu      0.5  concat_across_sum_of_layers
# 8            32  0.01       True  relu      0.0  concat_across_sum_of_layers
# 9            32  0.01       True  relu      0.5  concat_across_sum_of_layers
# 10          128  0.01       True  relu      0.0  concat_across_sum_of_layers
# 11          128  0.01       True  relu      0.5  concat_across_sum_of_layers
# 12           32  0.01       True  relu      0.0  concat_across_sum_of_layers
# 13           32  0.01       True  relu      0.5  concat_across_sum_of_layers
# 14          128  0.01       True  relu      0.0  concat_across_sum_of_layers
# 15          128  0.01       True  relu      0.5  concat_across_sum_of_layers
# 16           32  0.01       True  relu      0.0  concat_across_sum_of_layers
# 17           32  0.01       True  relu      0.5  concat_across_sum_of_layers
# 18          128  0.01       True  relu      0.0  concat_across_sum_of_layers
# 19          128  0.01       True  relu      0.5  concat_across_sum_of_layers
# 20           32  0.01       True  relu      0.0  concat_across_sum_of_layers
# 21           32  0.01       True  relu      0.5  concat_across_sum_of_layers
# 22          128  0.01       True  relu      0.0  concat_across_sum_of_layers
# 23          128  0.01       True  relu      0.5  concat_across_sum_of_layers
# 24           32  0.01       True  relu      0.0  concat_across_sum_of_layers
# 25           32  0.01       True  relu      0.5  concat_across_sum_of_layers
# 26          128  0.01       True  relu      0.0  concat_across_sum_of_layers
# 27          128  0.01       True  relu      0.5  concat_across_sum_of_layers
# 28           32  0.01       True  relu      0.0  concat_across_sum_of_layers
# 29           32  0.01       True  relu      0.5  concat_across_sum_of_layers
# 30          128  0.01       True  relu      0.0  concat_across_sum_of_layers
# 31          128  0.01       True  relu      0.5  concat_across_sum_of_layers
# 32           32  0.01       True  relu      0.0  concat_across_sum_of_layers
# 33           32  0.01       True  relu      0.5  concat_across_sum_of_layers
# 34          128  0.01       True  relu      0.0  concat_across_sum_of_layers
# 35          128  0.01       True  relu      0.5  concat_across_sum_of_layers
# 36           32  0.01       True  relu      0.0  concat_across_sum_of_layers
# 37           32  0.01       True  relu      0.5  concat_across_sum_of_layers
# 38          128  0.01       True  relu      0.0  concat_across_sum_of_layers
# 39          128  0.01       True  relu      0.5  concat_across_sum_of_layers
# 40           32  0.01       True  relu      0.0  concat_across_sum_of_layers
# 41           32  0.01       True  relu      0.5  concat_across_sum_of_layers
# 42          128  0.01       True  relu      0.0  concat_across_sum_of_layers
# 43          128  0.01       True  relu      0.5  concat_across_sum_of_layers
# 44           32  0.01       True  relu      0.0  concat_across_sum_of_layers
# 45           32  0.01       True  relu      0.5  concat_across_sum_of_layers
# 46          128  0.01       True  relu      0.0  concat_across_sum_of_layers
# 47          128  0.01       True  relu      0.5  concat_across_sum_of_layers
# 48           32  0.01       True  relu      0.0  concat_across_sum_of_layers
# 49           32  0.01       True  relu      0.5  concat_across_sum_of_layers
# 50          128  0.01       True  relu      0.0  concat_across_sum_of_layers
# 51          128  0.01       True  relu      0.5  concat_across_sum_of_layers
# 52           32  0.01       True  relu      0.0  concat_across_sum_of_layers
# 53           32  0.01       True  relu      0.5  concat_across_sum_of_layers
# 54          128  0.01       True  relu      0.0  concat_across_sum_of_layers
# 55          128  0.01       True  relu      0.5  concat_across_sum_of_layers
# 56           32  0.01       True  relu      0.0  concat_across_sum_of_layers
# 57           32  0.01       True  relu      0.5  concat_across_sum_of_layers
# 58          128  0.01       True  relu      0.0  concat_across_sum_of_layers
# 59          128  0.01       True  relu      0.5  concat_across_sum_of_layers
# 60           32  0.01       True  relu      0.0  concat_across_sum_of_layers
# 61           32  0.01       True  relu      0.5  concat_across_sum_of_layers
# 62          128  0.01       True  relu      0.0  concat_across_sum_of_layers
# 63          128  0.01       True  relu      0.5  concat_across_sum_of_layers
# 64           32  0.01       True  relu      0.0  concat_across_sum_of_layers
# 65           32  0.01       True  relu      0.5  concat_across_sum_of_layers
# 66          128  0.01       True  relu      0.0  concat_across_sum_of_layers
# 67          128  0.01       True  relu      0.5  concat_across_sum_of_layers
# 68           32  0.01       True  relu      0.0  concat_across_sum_of_layers
# 69           32  0.01       True  relu      0.5  concat_across_sum_of_layers
# 70          128  0.01       True  relu      0.0  concat_across_sum_of_layers
# 71          128  0.01       True  relu      0.5  concat_across_sum_of_layers
# 72           32  0.01       True  relu      0.0  concat_across_sum_of_layers
# 73           32  0.01       True  relu      0.5  concat_across_sum_of_layers
# 74          128  0.01       True  relu      0.0  concat_across_sum_of_layers
# 75          128  0.01       True  relu      0.5  concat_across_sum_of_layers
# 76           32  0.01       True  relu      0.0  concat_across_sum_of_layers
# 77           32  0.01       True  relu      0.5  concat_across_sum_of_layers
# 78          128  0.01       True  relu      0.0  concat_across_sum_of_layers
# 79          128  0.01       True  relu      0.5  concat_across_sum_of_layers
# 80           32  0.01       True  relu      0.0  concat_across_sum_of_layers
# 81           32  0.01       True  relu      0.5  concat_across_sum_of_layers
# 82          128  0.01       True  relu      0.0  concat_across_sum_of_layers
# 83          128  0.01       True  relu      0.5  concat_across_sum_of_layers
# 84           32  0.01       True  relu      0.0  concat_across_sum_of_layers
# 85           32  0.01       True  relu      0.5  concat_across_sum_of_layers
# 86          128  0.01       True  relu      0.0  concat_across_sum_of_layers
# 87          128  0.01       True  relu      0.5  concat_across_sum_of_layers
# 88           32  0.01       True  relu      0.0  concat_across_sum_of_layers
# 89           32  0.01       True  relu      0.5  concat_across_sum_of_layers
# 90          128  0.01       True  relu      0.0  concat_across_sum_of_layers
# 91          128  0.01       True  relu      0.5  concat_across_sum_of_layers
# 92           32  0.01       True  relu      0.0  concat_across_sum_of_layers
# 93           32  0.01       True  relu      0.5  concat_across_sum_of_layers
# 94          128  0.01       True  relu      0.0  concat_across_sum_of_layers
# 95          128  0.01       True  relu      0.5  concat_across_sum_of_layers
# 96           32  0.01       True  relu      0.0  concat_across_sum_of_layers
# 97           32  0.01       True  relu      0.5  concat_across_sum_of_layers
# 98          128  0.01       True  relu      0.0  concat_across_sum_of_layers
# 99          128  0.01       True  relu      0.5  concat_across_sum_of_layers
# 100          32  0.01       True  relu      0.0  concat_across_sum_of_layers
# 101          32  0.01       True  relu      0.5  concat_across_sum_of_layers
# 102         128  0.01       True  relu      0.0  concat_across_sum_of_layers
# 103         128  0.01       True  relu      0.5  concat_across_sum_of_layers
# 104          32  0.01       True  relu      0.0  concat_across_sum_of_layers
# 105          32  0.01       True  relu      0.5  concat_across_sum_of_layers
# 106         128  0.01       True  relu      0.0  concat_across_sum_of_layers
# 107         128  0.01       True  relu      0.5  concat_across_sum_of_layers
# 108          32  0.01       True  relu      0.0  concat_across_sum_of_layers
# 109          32  0.01       True  relu      0.5  concat_across_sum_of_layers
# 110         128  0.01       True  relu      0.0  concat_across_sum_of_layers
# 111         128  0.01       True  relu      0.5  concat_across_sum_of_layers
# 112          32  0.01       True  relu      0.0  concat_across_sum_of_layers
# 113          32  0.01       True  relu      0.5  concat_across_sum_of_layers
# 114         128  0.01       True  relu      0.0  concat_across_sum_of_layers
# 115         128  0.01       True  relu      0.5  concat_across_sum_of_layers
# 116          32  0.01       True  relu      0.0  concat_across_sum_of_layers
# 117          32  0.01       True  relu      0.5  concat_across_sum_of_layers
# 118         128  0.01       True  relu      0.0  concat_across_sum_of_layers
# 119         128  0.01       True  relu      0.5  concat_across_sum_of_layers
# 120          32  0.01       True  relu      0.0  concat_across_sum_of_layers
# 121          32  0.01       True  relu      0.5  concat_across_sum_of_layers
# 122         128  0.01       True  relu      0.0  concat_across_sum_of_layers
# 123         128  0.01       True  relu      0.5  concat_across_sum_of_layers
# 124          32  0.01       True  relu      0.0  concat_across_sum_of_layers
# 125          32  0.01       True  relu      0.5  concat_across_sum_of_layers
# 126         128  0.01       True  relu      0.0  concat_across_sum_of_layers
# 127         128  0.01       True  relu      0.5  concat_across_sum_of_layers
# 128          32  0.01       True  relu      0.0  concat_across_sum_of_layers
# 129          32  0.01       True  relu      0.5  concat_across_sum_of_layers
# 130         128  0.01       True  relu      0.0  concat_across_sum_of_layers
# 131         128  0.01       True  relu      0.5  concat_across_sum_of_layers
# 132          32  0.01       True  relu      0.0  concat_across_sum_of_layers
# 133          32  0.01       True  relu      0.5  concat_across_sum_of_layers
# 134         128  0.01       True  relu      0.0  concat_across_sum_of_layers
# 135         128  0.01       True  relu      0.5  concat_across_sum_of_layers
# 136          32  0.01       True  relu      0.0  concat_across_sum_of_layers
# 137          32  0.01       True  relu      0.5  concat_across_sum_of_layers
# 138         128  0.01       True  relu      0.0  concat_across_sum_of_layers
# 139         128  0.01       True  relu      0.5  concat_across_sum_of_layers
# 140          32  0.01       True  relu      0.0  concat_across_sum_of_layers
# 141          32  0.01       True  relu      0.5  concat_across_sum_of_layers
# 142         128  0.01       True  relu      0.0  concat_across_sum_of_layers
# 143         128  0.01       True  relu      0.5  concat_across_sum_of_layers
# 144          32  0.01       True  relu      0.0  concat_across_sum_of_layers
# 145          32  0.01       True  relu      0.5  concat_across_sum_of_layers
# 146         128  0.01       True  relu      0.0  concat_across_sum_of_layers
# 147         128  0.01       True  relu      0.5  concat_across_sum_of_layers
# 148          32  0.01       True  relu      0.0  concat_across_sum_of_layers
# 149          32  0.01       True  relu      0.5  concat_across_sum_of_layers
# 150         128  0.01       True  relu      0.0  concat_across_sum_of_layers
# 151         128  0.01       True  relu      0.5  concat_across_sum_of_layers
# 152          32  0.01       True  relu      0.0  concat_across_sum_of_layers
# 153          32  0.01       True  relu      0.5  concat_across_sum_of_layers
# 154         128  0.01       True  relu      0.0  concat_across_sum_of_layers
# 155         128  0.01       True  relu      0.5  concat_across_sum_of_layers
# 156          32  0.01       True  relu      0.0  concat_across_sum_of_layers
# 157          32  0.01       True  relu      0.5  concat_across_sum_of_layers
# 158         128  0.01       True  relu      0.0  concat_across_sum_of_layers
# 159         128  0.01       True  relu      0.5  concat_across_sum_of_layers
# 160          32  0.01       True  relu      0.0  concat_across_sum_of_layers
# 161          32  0.01       True  relu      0.5  concat_across_sum_of_layers
# 162         128  0.01       True  relu      0.0  concat_across_sum_of_layers
# 163         128  0.01       True  relu      0.5  concat_across_sum_of_layers
# 164          32  0.01       True  relu      0.0  concat_across_sum_of_layers
# 165          32  0.01       True  relu      0.5  concat_across_sum_of_layers
# 166         128  0.01       True  relu      0.0  concat_across_sum_of_layers
# 167         128  0.01       True  relu      0.5  concat_across_sum_of_layers
# 168          32  0.01       True  relu      0.0  concat_across_sum_of_layers
# 169          32  0.01       True  relu      0.5  concat_across_sum_of_layers
# 170         128  0.01       True  relu      0.0  concat_across_sum_of_layers
# 171         128  0.01       True  relu      0.5  concat_across_sum_of_layers
# 172          32  0.01       True  relu      0.0  concat_across_sum_of_layers
# 173          32  0.01       True  relu      0.5  concat_across_sum_of_layers
# 174         128  0.01       True  relu      0.0  concat_across_sum_of_layers
# 175         128  0.01       True  relu      0.5  concat_across_sum_of_layers
# 176          32  0.01       True  relu      0.0  concat_across_sum_of_layers
# 177          32  0.01       True  relu      0.5  concat_across_sum_of_layers
# 178         128  0.01       True  relu      0.0  concat_across_sum_of_layers
# 179         128  0.01       True  relu      0.5  concat_across_sum_of_layers
# 180          32  0.01       True  relu      0.0  concat_across_sum_of_layers
# 181          32  0.01       True  relu      0.5  concat_across_sum_of_layers
# 182         128  0.01       True  relu      0.0  concat_across_sum_of_layers
# 183         128  0.01       True  relu      0.5  concat_across_sum_of_layers
# 184          32  0.01       True  relu      0.0  concat_across_sum_of_layers
# 185          32  0.01       True  relu      0.5  concat_across_sum_of_layers
# 186         128  0.01       True  relu      0.0  concat_across_sum_of_layers
# 187         128  0.01       True  relu      0.5  concat_across_sum_of_layers
# 188          32  0.01       True  relu      0.0  concat_across_sum_of_layers
# 189          32  0.01       True  relu      0.5  concat_across_sum_of_layers
# 190         128  0.01       True  relu      0.0  concat_across_sum_of_layers
# 191         128  0.01       True  relu      0.5  concat_across_sum_of_layers
# 192          32  0.01       True  relu      0.0  concat_across_sum_of_layers
# 193          32  0.01       True  relu      0.5  concat_across_sum_of_layers
# 194         128  0.01       True  relu      0.0  concat_across_sum_of_layers
# 195         128  0.01       True  relu      0.5  concat_across_sum_of_layers
# 196          32  0.01       True  relu      0.0  concat_across_sum_of_layers
# 197          32  0.01       True  relu      0.5  concat_across_sum_of_layers
# 198         128  0.01       True  relu      0.0  concat_across_sum_of_layers
# 199         128  0.01       True  relu      0.5  concat_across_sum_of_layers
# 200          32  0.01       True  relu      0.0  concat_across_sum_of_layers
# 201          32  0.01       True  relu      0.5  concat_across_sum_of_layers
# 202         128  0.01       True  relu      0.0  concat_across_sum_of_layers
# 203         128  0.01       True  relu      0.5  concat_across_sum_of_layers
# 204          32  0.01       True  relu      0.0  concat_across_sum_of_layers
# 205          32  0.01       True  relu      0.5  concat_across_sum_of_layers
# 206         128  0.01       True  relu      0.0  concat_across_sum_of_layers
# 207         128  0.01       True  relu      0.5  concat_across_sum_of_layers
# 208          32  0.01       True  relu      0.0  concat_across_sum_of_layers
# 209          32  0.01       True  relu      0.5  concat_across_sum_of_layers
# 210         128  0.01       True  relu      0.0  concat_across_sum_of_layers
# 211         128  0.01       True  relu      0.5  concat_across_sum_of_layers
# 212          32  0.01       True  relu      0.0  concat_across_sum_of_layers
# 213          32  0.01       True  relu      0.5  concat_across_sum_of_layers
# 214         128  0.01       True  relu      0.0  concat_across_sum_of_layers
# 215         128  0.01       True  relu      0.5  concat_across_sum_of_layers
# 216          32  0.01       True  relu      0.0  concat_across_sum_of_layers
# 217          32  0.01       True  relu      0.0  concat_across_sum_of_layers
# 218          32  0.01       True  relu      0.5  concat_across_sum_of_layers
# 219          32  0.01       True  relu      0.5  concat_across_sum_of_layers
# 220         128  0.01       True  relu      0.0  concat_across_sum_of_layers
# 221         128  0.01       True  relu      0.0  concat_across_sum_of_layers
# 222         128  0.01       True  relu      0.5  concat_across_sum_of_layers
# 223         128  0.01       True  relu      0.5  concat_across_sum_of_layers
# 224          32  0.01       True  relu      0.0  concat_across_sum_of_layers
# 225          32  0.01       True  relu      0.0  concat_across_sum_of_layers
# 226          32  0.01       True  relu      0.5  concat_across_sum_of_layers
# 227          32  0.01       True  relu      0.5  concat_across_sum_of_layers
# 228         128  0.01       True  relu      0.0  concat_across_sum_of_layers
# 229         128  0.01       True  relu      0.0  concat_across_sum_of_layers
# 230         128  0.01       True  relu      0.5  concat_across_sum_of_layers
# 231         128  0.01       True  relu      0.5  concat_across_sum_of_layers
# 232          32  0.01       True  relu      0.0  concat_across_sum_of_layers
# 233          32  0.01       True  relu      0.0  concat_across_sum_of_layers
# 234          32  0.01       True  relu      0.5  concat_across_sum_of_layers
# 235          32  0.01       True  relu      0.5  concat_across_sum_of_layers
# 236         128  0.01       True  relu      0.0  concat_across_sum_of_layers
# 237         128  0.01       True  relu      0.0  concat_across_sum_of_layers
# 238         128  0.01       True  relu      0.5  concat_across_sum_of_layers
# 239         128  0.01       True  relu      0.5  concat_across_sum_of_layers
# 240          32  0.01       True  relu      0.0  concat_across_sum_of_layers
# 241          32  0.01       True  relu      0.0  concat_across_sum_of_layers
# 242          32  0.01       True  relu      0.5  concat_across_sum_of_layers
# 243          32  0.01       True  relu      0.5  concat_across_sum_of_layers
# 244         128  0.01       True  relu      0.0  concat_across_sum_of_layers
# 245         128  0.01       True  relu      0.0  concat_across_sum_of_layers
# 246         128  0.01       True  relu      0.5  concat_across_sum_of_layers
# 247         128  0.01       True  relu      0.5  concat_across_sum_of_layers
# 248          32  0.01       True  relu      0.0  concat_across_sum_of_layers
# 249          32  0.01       True  relu      0.0  concat_across_sum_of_layers
# 250          32  0.01       True  relu      0.5  concat_across_sum_of_layers
# 251          32  0.01       True  relu      0.5  concat_across_sum_of_layers
# 252         128  0.01       True  relu      0.0  concat_across_sum_of_layers
# 253         128  0.01       True  relu      0.0  concat_across_sum_of_layers
# 254         128  0.01       True  relu      0.5  concat_across_sum_of_layers
# 255         128  0.01       True  relu      0.5  concat_across_sum_of_layers
# 256          32  0.01       True  relu      0.0  concat_across_sum_of_layers
# 257          32  0.01       True  relu      0.0  concat_across_sum_of_layers
# 258          32  0.01       True  relu      0.5  concat_across_sum_of_layers
# 259          32  0.01       True  relu      0.5  concat_across_sum_of_layers
# 260         128  0.01       True  relu      0.0  concat_across_sum_of_layers
# 261         128  0.01       True  relu      0.0  concat_across_sum_of_layers
# 262         128  0.01       True  relu      0.5  concat_across_sum_of_layers
# 263         128  0.01       True  relu      0.5  concat_across_sum_of_layers
#
#           scheduler  step_size  step_gamma     epoch  ckpt_epoch  \
# 0    step_lr_epochs         50         0.5  val_best        33.8
# 1    step_lr_epochs         50         0.5  val_best        67.9
# 2    step_lr_epochs         50         0.5  val_best        49.8
# 3    step_lr_epochs         50         0.5  val_best        99.4
# 4    step_lr_epochs         50         0.5  val_best        62.9
# 5    step_lr_epochs         50         0.5  val_best        79.2
# 6    step_lr_epochs         50         0.5  val_best        37.3
# 7    step_lr_epochs         50         0.5  val_best        60.4
# 8    step_lr_epochs         50         0.5  val_best        51.1
# 9    step_lr_epochs         50         0.5  val_best        42.6
# 10   step_lr_epochs         50         0.5  val_best        55.0
# 11   step_lr_epochs         50         0.5  val_best        36.7
# 12   step_lr_epochs         50         0.5  val_best        81.7
# 13   step_lr_epochs         50         0.5  val_best        40.3
# 14   step_lr_epochs         50         0.5  val_best        38.1
# 15   step_lr_epochs         50         0.5  val_best        21.7
# 16   step_lr_epochs         50         0.5  val_best        41.6
# 17   step_lr_epochs         50         0.5  val_best        24.1
# 18   step_lr_epochs         50         0.5  val_best        37.2
# 19   step_lr_epochs         50         0.5  val_best        21.5
# 20   step_lr_epochs         50         0.5  val_best        96.1
# 21   step_lr_epochs         50         0.5  val_best        40.8
# 22   step_lr_epochs         50         0.5  val_best        34.9
# 23   step_lr_epochs         50         0.5  val_best        30.9
# 24   step_lr_epochs         50         0.5  val_best        90.6
# 25   step_lr_epochs         50         0.5  val_best        55.6
# 26   step_lr_epochs         50         0.5  val_best        33.8
# 27   step_lr_epochs         50         0.5  val_best        62.7
# 28   step_lr_epochs         50         0.5  val_best        64.7
# 29   step_lr_epochs         50         0.5  val_best        68.0
# 30   step_lr_epochs         50         0.5  val_best        49.4
# 31   step_lr_epochs         50         0.5  val_best        82.0
# 32   step_lr_epochs         50         0.5  val_best        47.8
# 33   step_lr_epochs         50         0.5  val_best        52.3
# 34   step_lr_epochs         50         0.5  val_best        27.6
# 35   step_lr_epochs         50         0.5  val_best        48.8
# 36   step_lr_epochs         50         0.5  val_best        67.7
# 37   step_lr_epochs         50         0.5  val_best        49.3
# 38   step_lr_epochs         50         0.5  val_best        64.4
# 39   step_lr_epochs         50         0.5  val_best        56.1
# 40   step_lr_epochs         50         0.5  val_best        51.4
# 41   step_lr_epochs         50         0.5  val_best        42.4
# 42   step_lr_epochs         50         0.5  val_best        47.6
# 43   step_lr_epochs         50         0.5  val_best        38.3
# 44   step_lr_epochs         50         0.5  val_best        42.2
# 45   step_lr_epochs         50         0.5  val_best        40.2
# 46   step_lr_epochs         50         0.5  val_best        34.5
# 47   step_lr_epochs         50         0.5  val_best        30.3
# 48   step_lr_epochs         50         0.5  val_best        67.5
# 49   step_lr_epochs         50         0.5  val_best        25.9
# 50   step_lr_epochs         50         0.5  val_best        43.0
# 51   step_lr_epochs         50         0.5  val_best        25.0
# 52   step_lr_epochs         50         0.5  val_best        61.7
# 53   step_lr_epochs         50         0.5  val_best        35.5
# 54   step_lr_epochs         50         0.5  val_best        62.7
# 55   step_lr_epochs         50         0.5  val_best        42.0
# 56   step_lr_epochs         50         0.5  val_best        36.6
# 57   step_lr_epochs         50         0.5  val_best        46.4
# 58   step_lr_epochs         50         0.5  val_best        34.8
# 59   step_lr_epochs         50         0.5  val_best        34.6
# 60   step_lr_epochs         50         0.5  val_best        49.6
# 61   step_lr_epochs         50         0.5  val_best        18.0
# 62   step_lr_epochs         50         0.5  val_best        45.0
# 63   step_lr_epochs         50         0.5  val_best        12.3
# 64   step_lr_epochs         50         0.5  val_best        75.9
# 65   step_lr_epochs         50         0.5  val_best        51.0
# 66   step_lr_epochs         50         0.5  val_best        60.0
# 67   step_lr_epochs         50         0.5  val_best        42.5
# 68   step_lr_epochs         50         0.5  val_best        45.3
# 69   step_lr_epochs         50         0.5  val_best        23.4
# 70   step_lr_epochs         50         0.5  val_best        50.5
# 71   step_lr_epochs         50         0.5  val_best        15.4
# 72   step_lr_epochs         50         0.5  val_best       162.7
# 73   step_lr_epochs         50         0.5  val_best       204.0
# 74   step_lr_epochs         50         0.5  val_best       115.8
# 75   step_lr_epochs         50         0.5  val_best       164.9
# 76   step_lr_epochs         50         0.5  val_best        99.4
# 77   step_lr_epochs         50         0.5  val_best       102.3
# 78   step_lr_epochs         50         0.5  val_best       104.6
# 79   step_lr_epochs         50         0.5  val_best       200.0
# 80   step_lr_epochs         50         0.5  val_best       130.4
# 81   step_lr_epochs         50         0.5  val_best       161.5
# 82   step_lr_epochs         50         0.5  val_best       121.1
# 83   step_lr_epochs         50         0.5  val_best        99.0
# 84   step_lr_epochs         50         0.5  val_best       107.3
# 85   step_lr_epochs         50         0.5  val_best        87.4
# 86   step_lr_epochs         50         0.5  val_best       113.2
# 87   step_lr_epochs         50         0.5  val_best        83.0
# 88   step_lr_epochs         50         0.5  val_best       163.8
# 89   step_lr_epochs         50         0.5  val_best       111.1
# 90   step_lr_epochs         50         0.5  val_best        83.9
# 91   step_lr_epochs         50         0.5  val_best        83.0
# 92   step_lr_epochs         50         0.5  val_best       208.6
# 93   step_lr_epochs         50         0.5  val_best       104.3
# 94   step_lr_epochs         50         0.5  val_best       173.8
# 95   step_lr_epochs         50         0.5  val_best        95.9
# 96   step_lr_epochs         50         0.5  val_best       143.1
# 97   step_lr_epochs         50         0.5  val_best       134.2
# 98   step_lr_epochs         50         0.5  val_best       119.8
# 99   step_lr_epochs         50         0.5  val_best        90.6
# 100  step_lr_epochs         50         0.5  val_best       176.4
# 101  step_lr_epochs         50         0.5  val_best       121.8
# 102  step_lr_epochs         50         0.5  val_best       103.9
# 103  step_lr_epochs         50         0.5  val_best        68.8
# 104  step_lr_epochs         50         0.5  val_best       111.6
# 105  step_lr_epochs         50         0.5  val_best       167.0
# 106  step_lr_epochs         50         0.5  val_best        96.0
# 107  step_lr_epochs         50         0.5  val_best       201.5
# ...
# 229    0.7000        0.0456     0.6798         0.0915  0.5350      0.1190
# 230    0.7171        0.0357     0.7470         0.0948  0.4895      0.1203
# 231    0.7162        0.0555     0.7232         0.0957  0.5098      0.1354
# 232    0.7964        0.0237     0.7900         0.0365  0.8004      0.0355
# 233    0.8058        0.0177     0.7959         0.0329  0.8178      0.0367
# 234    0.7365        0.0200     0.7345         0.0411  0.7377      0.0500
# 235    0.7306        0.0200     0.7119         0.0272  0.7683      0.0651
# 236    0.7952        0.0201     0.7769         0.0323  0.8210      0.0304
# 237    0.7981        0.0234     0.7890         0.0365  0.8081      0.0320
# 238    0.7362        0.0255     0.7746         0.0329  0.6567      0.0663
# 239    0.7450        0.0256     0.7432         0.0485  0.7435      0.0435
# 240    0.8010        0.0292     0.7935         0.0413  0.8082      0.0287
# 241    0.7869        0.0231     0.7758         0.0342  0.7992      0.0263
# 242    0.7689        0.0174     0.7859         0.0396  0.7347      0.0457
# 243    0.7406        0.0143     0.7363         0.0372  0.7437      0.0440
# 244    0.7871        0.0203     0.7875         0.0347  0.7800      0.0386
# 245    0.7857        0.0195     0.7881         0.0381  0.7774      0.0355
# 246    0.7501        0.0179     0.7458         0.0388  0.7533      0.0539
# 247    0.7448        0.0319     0.7894         0.0336  0.6671      0.0953
# 248    0.7324        0.0599     0.6714         0.0777  0.6579      0.1115
# 249    0.7189        0.0487     0.6683         0.0974  0.6458      0.1268
# 250    0.7171        0.0495     0.6937         0.0853  0.5177      0.1149
# 251    0.7333        0.0313     0.7092         0.0824  0.5636      0.0843
# 252    0.7108        0.0400     0.6688         0.0680  0.5519      0.1580
# 253    0.7432        0.0378     0.7132         0.0650  0.6013      0.1144
# 254    0.7361        0.0417     0.7212         0.0775  0.5440      0.0932
# 255    0.7243        0.0524     0.7128         0.0698  0.5087      0.1699
# 256    0.7369        0.0582     0.6882         0.0873  0.6305      0.1012
# 257    0.7297        0.0388     0.7000         0.0845  0.6002      0.1464
# 258    0.7225        0.0309     0.6876         0.0676  0.5626      0.1324
# 259    0.7189        0.0439     0.6989         0.0970  0.5384      0.0705
# 260    0.7333        0.0503     0.6777         0.0718  0.6396      0.1161
# 261    0.7207        0.0542     0.6519         0.0880  0.6569      0.0932
# 262    0.7072        0.0340     0.7271         0.0679  0.4288      0.1285
# 263    0.7198        0.0341     0.6827         0.0729  0.5620      0.0713
#
#          f1  f1_std     auc  auc_std  layers_mp
# 0    0.6500  0.0730  0.8049   0.0553        NaN
# 1    0.6357  0.0530  0.8054   0.0419        NaN
# 2    0.6453  0.0733  0.8178   0.0401        NaN
# 3    0.6198  0.0719  0.8190   0.0437        NaN
# 4    0.6417  0.0567  0.8158   0.0424        NaN
# 5    0.6379  0.0600  0.8166   0.0435        NaN
# 6    0.6409  0.0488  0.8102   0.0497        NaN
# 7    0.6075  0.0479  0.8202   0.0395        NaN
# 8    0.6954  0.0513  0.8345   0.0470        NaN
# 9    0.6823  0.0593  0.8124   0.0649        NaN
# 10   0.7351  0.0406  0.8482   0.0391        NaN
# 11   0.6876  0.0851  0.8328   0.0481        NaN
# 12   0.6874  0.0572  0.8311   0.0448        NaN
# 13   0.6755  0.0684  0.8403   0.0422        NaN
# 14   0.7109  0.0522  0.8429   0.0511        NaN
# 15   0.6668  0.0477  0.8343   0.0461        NaN
# 16   0.6822  0.0625  0.8296   0.0408        NaN
# 17   0.6936  0.0610  0.8339   0.0348        NaN
# 18   0.6942  0.0495  0.8279   0.0460        NaN
# 19   0.6851  0.0745  0.8372   0.0373        NaN
# 20   0.6856  0.0481  0.8101   0.0357        NaN
# 21   0.7095  0.0714  0.8420   0.0406        NaN
# 22   0.7087  0.0627  0.8274   0.0504        NaN
# 23   0.6850  0.0673  0.8257   0.0388        NaN
# 24   0.6481  0.0416  0.8152   0.0395        NaN
# 25   0.5975  0.0578  0.8117   0.0466        NaN
# 26   0.6543  0.0408  0.8161   0.0310        NaN
# 27   0.6398  0.0639  0.8219   0.0401        NaN
# 28   0.6233  0.0640  0.8179   0.0333        NaN
# 29   0.6488  0.0641  0.8310   0.0284        NaN
# 30   0.6277  0.0525  0.8197   0.0452        NaN
# 31   0.6014  0.0966  0.8152   0.0375        NaN
# 32   0.7068  0.0421  0.8406   0.0428        NaN
# 33   0.6826  0.0757  0.8350   0.0372        NaN
# 34   0.7223  0.0660  0.8472   0.0266        NaN
# 35   0.6652  0.0576  0.8057   0.0429        NaN
# 36   0.7175  0.0478  0.8408   0.0477        NaN
# 37   0.6389  0.0713  0.8279   0.0422        NaN
# 38   0.7054  0.0824  0.8384   0.0371        NaN
# 39   0.6667  0.0497  0.8113   0.0526        NaN
# 40   0.7139  0.0774  0.8354   0.0423        NaN
# 41   0.6723  0.0622  0.8147   0.0477        NaN
# 42   0.7045  0.0569  0.8404   0.0440        NaN
# 43   0.6747  0.0955  0.8357   0.0360        NaN
# 44   0.7130  0.0823  0.8297   0.0583        NaN
# 45   0.6576  0.0364  0.8305   0.0434        NaN
# 46   0.7402  0.0695  0.8492   0.0351        NaN
# 47   0.6831  0.0669  0.8459   0.0356        NaN
# 48   0.6521  0.0762  0.8199   0.0441        NaN
# 49   0.6561  0.0844  0.8281   0.0439        NaN
# 50   0.6964  0.0638  0.8149   0.0505        NaN
# 51   0.6707  0.0471  0.8340   0.0431        NaN
# 52   0.6707  0.0834  0.8225   0.0523        NaN
# 53   0.6445  0.0516  0.8357   0.0462        NaN
# 54   0.6987  0.0561  0.8336   0.0465        NaN
# 55   0.6485  0.0725  0.8221   0.0341        NaN
# 56   0.6975  0.0676  0.8186   0.0414        NaN
# 57   0.6062  0.0730  0.8251   0.0433        NaN
# 58   0.7250  0.0401  0.8339   0.0462        NaN
# 59   0.6486  0.0641  0.8293   0.0482        NaN
# 60   0.6985  0.0710  0.8272   0.0442        NaN
# 61   0.6404  0.0803  0.8366   0.0500        NaN
# 62   0.7088  0.0495  0.8248   0.0445        NaN
# 63   0.6526  0.0689  0.8305   0.0456        NaN
# 64   0.7005  0.0494  0.8391   0.0358        NaN
# 65   0.6507  0.0845  0.8209   0.0389        NaN
# 66   0.7225  0.0465  0.8274   0.0368        NaN
# 67   0.6385  0.0465  0.8147   0.0522        NaN
# 68   0.6977  0.0541  0.8228   0.0468        NaN
# 69   0.6669  0.0418  0.8292   0.0520        NaN
# 70   0.7138  0.0483  0.8300   0.0490        NaN
# 71   0.6466  0.0943  0.8100   0.0506        NaN
# 72   0.8070  0.0279  0.8689   0.0186        NaN
# 73   0.7575  0.0294  0.8253   0.0328        NaN
# 74   0.8004  0.0234  0.8684   0.0161        NaN
# 75   0.7522  0.0305  0.8294   0.0272        NaN
# 76   0.8048  0.0226  0.8694   0.0221        NaN
# 77   0.7555  0.0294  0.8329   0.0245        NaN
# 78   0.8030  0.0279  0.8666   0.0219        NaN
# 79   0.7637  0.0443  0.8359   0.0339        NaN
# 80   0.7978  0.0321  0.8671   0.0190        NaN
# 81   0.7494  0.0260  0.8271   0.0202        NaN
# 82   0.7857  0.0289  0.8589   0.0207        NaN
# 83   0.7548  0.0266  0.8274   0.0212        NaN
# 84   0.7948  0.0265  0.8695   0.0183        NaN
# 85   0.7579  0.0215  0.8279   0.0182        NaN
# 86   0.8021  0.0266  0.8702   0.0175        NaN
# 87   0.7475  0.0227  0.8220   0.0223        NaN
# 88   0.7954  0.0277  0.8626   0.0185        NaN
# 89   0.7550  0.0279  0.8223   0.0185        NaN
# 90   0.7960  0.0205  0.8622   0.0185        NaN
# 91   0.7242  0.0266  0.7995   0.0230        NaN
# 92   0.8000  0.0261  0.8703   0.0206        NaN
# 93   0.7502  0.0214  0.8265   0.0153        NaN
# 94   0.7906  0.0281  0.8603   0.0199        NaN
# 95   0.7400  0.0236  0.8152   0.0169        NaN
# 96   0.8052  0.0278  0.8749   0.0198        NaN
# 97   0.7601  0.0276  0.8296   0.0223        NaN
# 98   0.8079  0.0224  0.8766   0.0197        NaN
# 99   0.7756  0.0214  0.8401   0.0175        NaN
# 100  0.8034  0.0243  0.8778   0.0163        NaN
# 101  0.7642  0.0262  0.8373   0.0163        NaN
# 102  0.8092  0.0200  0.8806   0.0140        NaN
# 103  0.7681  0.0201  0.8371   0.0161        NaN
# 104  0.8045  0.0254  0.8789   0.0185        NaN
# 105  0.7598  0.0217  0.8302   0.0208        NaN
# 106  0.7999  0.0263  0.8634   0.0193        NaN
# 107  0.7596  0.0236  0.8288   0.0199        NaN
# 108  0.8046  0.0236  0.8768   0.0188        NaN
# 109  0.7628  0.0330  0.8389   0.0224        NaN
# 110  0.8076  0.0255  0.8801   0.0166        NaN
# 111  0.7617  0.0260  0.8365   0.0212        NaN
# 112  0.8111  0.0261  0.8807   0.0215        NaN
# 113  0.7506  0.0227  0.8199   0.0216        NaN
# 114  0.7980  0.0405  0.8636   0.0291        NaN
# 115  0.7601  0.0277  0.8301   0.0242        NaN
# 116  0.8070  0.0203  0.8765   0.0154        NaN
# 117  0.7613  0.0221  0.8340   0.0193        NaN
# 118  0.8123  0.0219  0.8768   0.0171        NaN
# 119  0.7616  0.0323  0.8277   0.0253        NaN
# 120  0.8037  0.0229  0.8715   0.0199        NaN
# 121  0.7402  0.0253  0.8204   0.0209        NaN
# 122  0.7988  0.0217  0.8694   0.0192        NaN
# 123  0.7471  0.0192  0.8259   0.0164        NaN
# 124  0.8051  0.0251  0.8759   0.0172        NaN
# 125  0.7406  0.0146  0.8219   0.0124        NaN
# 126  0.8024  0.0233  0.8697   0.0146        NaN
# 127  0.7602  0.0266  0.8310   0.0195        NaN
# 128  0.7997  0.0198  0.8688   0.0185        NaN
# 129  0.7322  0.0263  0.8069   0.0177        NaN
# 130  0.7997  0.0236  0.8672   0.0147        NaN
# 131  0.7236  0.0375  0.8025   0.0293        NaN
# 132  0.8088  0.0272  0.8741   0.0232        NaN
# 133  0.7480  0.0159  0.8219   0.0113        NaN
# 134  0.8026  0.0255  0.8671   0.0240        NaN
# 135  0.7375  0.0255  0.8142   0.0186        NaN
# 136  0.7950  0.0234  0.8715   0.0154        NaN
# 137  0.7333  0.0263  0.8020   0.0280        NaN
# 138  0.7901  0.0265  0.8632   0.0228        NaN
# 139  0.7240  0.0329  0.8031   0.0305        NaN
# 140  0.8123  0.0252  0.8740   0.0197        NaN
# 141  0.7315  0.0297  0.8084   0.0291        NaN
# 142  0.8018  0.0206  0.8676   0.0173        NaN
# 143  0.7343  0.0194  0.8031   0.0111        NaN
# 144  0.6446  0.0448  0.7920   0.0637        NaN
# 145  0.6058  0.0770  0.7822   0.0601        NaN
# 146  0.6216  0.0864  0.7768   0.0500        NaN
# 147  0.6451  0.0528  0.7858   0.0638        NaN
# 148  0.6504  0.0457  0.8032   0.0589        NaN
# 149  0.6345  0.0517  0.7915   0.0493        NaN
# 150  0.6554  0.0480  0.7860   0.0591        NaN
# 151  0.6049  0.0654  0.7763   0.0617        NaN
# 152  0.6905  0.0505  0.8102   0.0522        NaN
# 153  0.6150  0.0717  0.7763   0.0539        NaN
# 154  0.6659  0.0497  0.7912   0.0622        NaN
# 155  0.6555  0.0323  0.7912   0.0610        NaN
# 156  0.6685  0.0538  0.8143   0.0559        NaN
# 157  0.6392  0.0467  0.7908   0.0396        NaN
# 158  0.6768  0.0622  0.8029   0.0457        NaN
# 159  0.6568  0.0669  0.7765   0.0507        NaN
# 160  0.6519  0.0757  0.7852   0.0526        NaN
# 161  0.6367  0.0640  0.7886   0.0501        NaN
# 162  0.6740  0.0547  0.7873   0.0508        NaN
# 163  0.6705  0.0600  0.7938   0.0532        NaN
# 164  0.6664  0.0402  0.8042   0.0460        NaN
# 165  0.6416  0.0509  0.7812   0.0499        NaN
# 166  0.6754  0.0665  0.7907   0.0470        NaN
# 167  0.6195  0.0593  0.7825   0.0642        NaN
# 168  0.6452  0.0731  0.7884   0.0492        NaN
# 169  0.6354  0.0482  0.8043   0.0393        NaN
# 170  0.6378  0.0606  0.8038   0.0535        NaN
# 171  0.6216  0.0825  0.7958   0.0645        NaN
# 172  0.6731  0.0490  0.8099   0.0476        NaN
# 173  0.6553  0.0404  0.7816   0.0506        NaN
# 174  0.6468  0.0503  0.7880   0.0484        NaN
# 175  0.5964  0.0886  0.7709   0.0622        NaN
# 176  0.6373  0.0459  0.7856   0.0539        NaN
# 177  0.6374  0.0587  0.7983   0.0426        NaN
# 178  0.6259  0.0628  0.7693   0.0554        NaN
# 179  0.5948  0.1060  0.7881   0.0553        NaN
# 180  0.6489  0.0652  0.7816   0.0655        NaN
# 181  0.6322  0.0570  0.7809   0.0528        NaN
# 182  0.6459  0.0668  0.7860   0.0576        NaN
# 183  0.5841  0.1010  0.7688   0.0690        NaN
# 184  0.6546  0.0515  0.7819   0.0618        NaN
# 185  0.6157  0.1077  0.7817   0.0612        NaN
# 186  0.6446  0.0352  0.7752   0.0436        NaN
# 187  0.6197  0.0777  0.7796   0.0570        NaN
# 188  0.6562  0.0372  0.7890   0.0491        NaN
# 189  0.6196  0.0833  0.7705   0.0658        NaN
# 190  0.6594  0.0584  0.7932   0.0604        NaN
# 191  0.6396  0.0591  0.7805   0.0578        NaN
# 192  0.6672  0.0226  0.7912   0.0507        NaN
# 193  0.6095  0.0970  0.7942   0.0450        NaN
# 194  0.6701  0.0609  0.7984   0.0498        NaN
# 195  0.5534  0.1489  0.7875   0.0523        NaN
# 196  0.6571  0.0566  0.7819   0.0672        NaN
# 197  0.6236  0.0842  0.7849   0.0590        NaN
# 198  0.6610  0.0683  0.8073   0.0553        NaN
# 199  0.5886  0.0727  0.7685   0.0511        NaN
# 200  0.6897  0.0743  0.8066   0.0595        NaN
# 201  0.6177  0.0515  0.7981   0.0413        NaN
# 202  0.6687  0.0556  0.7925   0.0541        NaN
# 203  0.5803  0.0981  0.7740   0.0602        NaN
# 204  0.6482  0.0712  0.8030   0.0638        NaN
# 205  0.6653  0.0470  0.7917   0.0459        NaN
# 206  0.6446  0.0486  0.7810   0.0543        NaN
# 207  0.6282  0.0726  0.7897   0.0565        NaN
# 208  0.6350  0.0465  0.7868   0.0576        NaN
# 209  0.6345  0.0891  0.8023   0.0492        NaN
# 210  0.6451  0.0733  0.7894   0.0584        NaN
# 211  0.5776  0.0646  0.7724   0.0497        NaN
# 212  0.6528  0.0523  0.7896   0.0518        NaN
# 213  0.6319  0.0813  0.7902   0.0448        NaN
# 214  0.6525  0.0679  0.8013   0.0511        NaN
# 215  0.6396  0.0755  0.7948   0.0408        NaN
# 216  0.6209  0.0763  0.8085   0.0528        5.0
# 217  0.6101  0.0337  0.8007   0.0366        3.0
# 218  0.6147  0.0927  0.8160   0.0518        3.0
# 219  0.6279  0.0795  0.8124   0.0641        5.0
# 220  0.6057  0.0737  0.7977   0.0560        5.0
# 221  0.5897  0.0672  0.7826   0.0465        3.0
# 222  0.5622  0.0906  0.8032   0.0494        3.0
# 223  0.5285  0.0966  0.7935   0.0511        5.0
# 224  0.5993  0.0527  0.8020   0.0536        5.0
# 225  0.6310  0.0782  0.8070   0.0587        2.0
# 226  0.6406  0.0608  0.8143   0.0442        2.0
# 227  0.6532  0.0549  0.8184   0.0498        5.0
# 228  0.5663  0.0684  0.7987   0.0487        2.0
# 229  0.5860  0.0644  0.7841   0.0602        5.0
# 230  0.5756  0.0765  0.8063   0.0418        5.0
# 231  0.5825  0.1140  0.8059   0.0601        2.0
# 232  0.7946  0.0293  0.8664   0.0215        3.0
# 233  0.8058  0.0219  0.8710   0.0177        5.0
# 234  0.7339  0.0236  0.8165   0.0210        3.0
# 235  0.7370  0.0278  0.8047   0.0275        5.0
# 236  0.7979  0.0250  0.8645   0.0212        5.0
# 237  0.7978  0.0260  0.8648   0.0225        3.0
# 238  0.7090  0.0440  0.8098   0.0327        3.0
# 239  0.7418  0.0311  0.8137   0.0220        5.0
# 240  0.8004  0.0304  0.8662   0.0227        5.0
# 241  0.7870  0.0274  0.8593   0.0200        2.0
# 242  0.7577  0.0255  0.8345   0.0170        2.0
# 243  0.7385  0.0227  0.8140   0.0160        5.0
# 244  0.7829  0.0272  0.8629   0.0201        2.0
# 245  0.7816  0.0219  0.8541   0.0194        5.0
# 246  0.7478  0.0278  0.8272   0.0153        5.0
# 247  0.7173  0.0550  0.8114   0.0221        2.0
# 248  0.6570  0.0704  0.7878   0.0636        3.0
# 249  0.6405  0.0503  0.7864   0.0606        5.0
# 250  0.5840  0.0892  0.7951   0.0544        5.0
# 251  0.6209  0.0564  0.7870   0.0564        3.0
# 252  0.5851  0.1157  0.7666   0.0588        5.0
# 253  0.6422  0.0708  0.7848   0.0555        3.0
# 254  0.6144  0.0747  0.8004   0.0552        5.0
# 255  0.5726  0.1511  0.7872   0.0538        3.0
# 256  0.6512  0.0765  0.7894   0.0628        5.0
# 257  0.6274  0.0719  0.7960   0.0542        2.0
# 258  0.6054  0.0797  0.7803   0.0396        5.0
# 259  0.6004  0.0419  0.7726   0.0616        2.0
# 260  0.6496  0.0730  0.7886   0.0570        2.0
# 261  0.6482  0.0615  0.7762   0.0630        5.0
# 262  0.5220  0.1095  0.7889   0.0444        2.0
# 263  0.6103  0.0395  0.7613   0.0647        5.0
