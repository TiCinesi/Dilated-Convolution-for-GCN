# %%
import pandas as pd

val = pd.read_csv(f'../../DL-project_results/ogbg_molhiv_baseline_grid_gin/agg/val_best.csv')
test = pd.read_csv(f'../../DL-project_results/ogbg_molhiv_baseline_grid_gin/agg/test_best.csv')

# %%
d = val.sort_values('auc', ascending=False)

d[d['type'] == 'dilated_gnn']
# Out:
#             type         layer  edges  k1  k2  batch_size  dropout  \
# 77   dilated_gnn  edge_ginconv   True   1   1         128      0.0
# 79   dilated_gnn  edge_ginconv   True   1   1         128      0.5
# 81   dilated_gnn  edge_ginconv   True   1   2          32      0.0
# 123  dilated_gnn  edge_ginconv   True   3   1          32      0.5
# 83   dilated_gnn  edge_ginconv   True   1   2          32      0.5
# ..           ...           ...    ...  ..  ..         ...      ...
# 104  dilated_gnn  edge_ginconv   True   2   2          32      0.0
# 76   dilated_gnn  edge_ginconv   True   1   1         128      0.0
# 136  dilated_gnn  edge_ginconv   True   3   3          32      0.0
# 88   dilated_gnn  edge_ginconv   True   1   3          32      0.0
# 114  dilated_gnn  edge_ginconv   True   2   3          32      0.5
#
#                            gpool     epoch  ckpt_epoch  ...  accuracy  \
# 77                          mean  val_best        96.9  ...    0.9781
# ...

# %%
d[d['type'] == 'dilapos_gnn']
# Out:
#            type         layer  edges  k1  k2  batch_size  dropout  \
# 7   dilapos_gnn  edge_ginconv   True   1   1         128      0.5
# 11  dilapos_gnn  edge_ginconv   True   1   2          32      0.5
# 5   dilapos_gnn  edge_ginconv   True   1   1         128      0.0
# 1   dilapos_gnn  edge_ginconv   True   1   1          32      0.0
# 38  dilapos_gnn  edge_ginconv   True   2   2         128      0.5
# ..          ...           ...    ...  ..  ..         ...      ...
# 28  dilapos_gnn  edge_ginconv   True   2   1         128      0.0
# 16  dilapos_gnn  edge_ginconv   True   1   3          32      0.0
# 64  dilapos_gnn  edge_ginconv   True   3   3          32      0.0
# 0   dilapos_gnn  edge_ginconv   True   1   1          32      0.0
# 4   dilapos_gnn  edge_ginconv   True   1   1         128      0.0
#
#                           gpool     epoch  ckpt_epoch  ...  accuracy  \
# 7                          mean  val_best        72.3  ...    0.9795
# ...

# %%
d
# Out:
#             type         layer  edges  k1  k2  batch_size  dropout  \
# 77   dilated_gnn  edge_ginconv   True   1   1         128      0.0
# 79   dilated_gnn  edge_ginconv   True   1   1         128      0.5
# 7    dilapos_gnn  edge_ginconv   True   1   1         128      0.5
# 11   dilapos_gnn  edge_ginconv   True   1   2          32      0.5
# 81   dilated_gnn  edge_ginconv   True   1   2          32      0.0
# ..           ...           ...    ...  ..  ..         ...      ...
# 64   dilapos_gnn  edge_ginconv   True   3   3          32      0.0
# 0    dilapos_gnn  edge_ginconv   True   1   1          32      0.0
# 88   dilated_gnn  edge_ginconv   True   1   3          32      0.0
# 4    dilapos_gnn  edge_ginconv   True   1   1         128      0.0
# 114  dilated_gnn  edge_ginconv   True   2   3          32      0.5
#
#                            gpool     epoch  ckpt_epoch  ...  accuracy  \
# 77                          mean  val_best        96.9  ...    0.9781
# ...
